# %% [markdown]
# ## Newspaper3k
#
# First we will try out the code from the [Newspaper3k documentation](https://newspaper.readthedocs.io/en/latest/).

# %%
from newspaper import Article

# %%
url = 'https://www.npr.org/2019/04/05/709847825/senators-to-consumer-watchdog-prove-youre-protecting-student-borrowers'
article = Article(url)

# %%
article.download()

# %%
article.html
# Out:
# '<!doctype html><html class="no-js" lang="en"><head><script>\n   try {var _sf_startpt=(new Date()).getTime();} catch(e){}\n</script>\n<meta itemscope itemtype="https://schema.org/SpeakableSpecification" itemref="speakable" /><title>Warren, Gillibrand to CFPB: Protect Public Service Loan Forgiveness : NPR</title><meta id="speakable" itemprop="cssSelector" content="[data-is-speakable]" /><meta id="google-site-verification" name="google-site-verification" content="1VqzbDm4ukeFVHOoq5LjIKA2fVKZD-EYv8cXZhKXSfU" /><meta charset="utf-8" /><meta name="robots" content="noarchive,index,follow" /><meta name="Rating" content="General" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="npr-pjax" /><meta name="date" content="2019-04-05" /><link rel="canonical" href="https://www.npr.org/2019/04/05/709847825/senators-to-consumer-watchdog-prove-youre-protecting-student-borrowers" /><meta name="description" content="Several top Democrats sent a stern l
# ...

# %%
article.parse()

# %%
article.authors
# Out:
# ['Cory Turner']

# %%
article.publish_date
# Out:
# datetime.datetime(2019, 4, 5, 0, 0)

# %%
article.text
# Out:
# 'Senators To Consumer Watchdog: Prove You\'re Protecting Student Borrowers\n\nEnlarge this image Hanna Barczyk for NPR Hanna Barczyk for NPR\n\nSix Democratic senators, including two presidential candidates, sent a letter to the head of the Consumer Financial Protection Bureau on Wednesday demanding that the agency prove it is policing the companies, known as servicers, that the government pays to manage its trillion-dollar, federal student loan portfolio.\n\n"We are concerned," the letter reads, "that CFPB leadership has abandoned its supervision and enforcement activities related to federal student loan servicers. This suggests a shocking disregard for the financial well-being of our nation\'s public servants, including teachers, first responders, and members of the military."\n\nThe letter, dated April 3, includes the signatures of Sens. Elizabeth Warren of Massachusetts and Kirsten Gillibrand of New York — both presidential contenders — as well as Dick Durbin of Illinois, Sherrod
# ...

# %%
article.top_image
# Out:
# 'https://media.npr.org/assets/img/2019/04/04/hbarczyk_npr_studentloan_final_wide-f6b6dcf8eddba344443f065f0b971eb4e7dbf73f.jpeg?s=1400'

# %%
article.movies
# Out:
# []

# %%
import nltk

# %% [markdown]
# When I tried to run `article.nlp`, I got an error `Resource punkt not found.` with instructions to run the following code:

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/michaelhornstein/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['student',
#  'protecting',
#  'loan',
#  'forgiveness',
#  'federal',
#  'qualify',
#  'watchdog',
#  'borrowers',
#  'told',
#  'senators',
#  'pslf',
#  'consumer',
#  'youre',
#  'servicers',
#  'cfpb',
#  'prove']

# %%
article.summary
# Out:
# 'Senators To Consumer Watchdog: Prove You\'re Protecting Student BorrowersEnlarge this image Hanna Barczyk for NPR Hanna Barczyk for NPRSix Democratic senators, including two presidential candidates, sent a letter to the head of the Consumer Financial Protection Bureau on Wednesday demanding that the agency prove it is policing the companies, known as servicers, that the government pays to manage its trillion-dollar, federal student loan portfolio.\n"We are concerned," the letter reads, "that CFPB leadership has abandoned its supervision and enforcement activities related to federal student loan servicers.\n"I thought, \'Oh great, I must qualify\' "Public Service Loan Forgiveness (PSLF) promises forgiveness to borrowers who make on-time loan payments for 10 years (120 payments) while working in public service.\nAll of this raises an important question that is at the heart of this new letter: Who is policing federal student loan servicers?\nDuring the Obama administration, the agency 
# ...
